# %% [markdown]
# <a href="https://colab.research.google.com/github/imanysr/DKB-IMANAMIL/blob/main/huhehehu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Bina array markah
# Out:
#   File "/tmp/ipykernel_3144/198596645.py", line 1
#     Bina array markah
#          ^
# SyntaxError: invalid syntax

# %%
import numpy as np

markah = np.array ([70,85,90,65,80])
print (markah)
# Out:
# [70 85 90 65 80]

# %% [markdown]
# KIRA MARKAH PURATA

# %%
purata = np.mean (markah)
print ("purata markah")
# Out:
# purata markah

# %%
tertinggi = np.max (markah)
print ("tertinggi markah:",tertinggi)
# Out:
# tertinggi markah: 90

# %%
terendah = np.min (markah)
print ("terendah markah:",terendah)
# Out:
# terendah markah: 65

# %% [markdown]
# JUMLAH

# %%
jumlah = np.sum (markah)
print ("jumlah markah:",jumlah)
# Out:
# jumlah markah: 390

# %% [markdown]
# TAMBAH

# %%
markah_baru = markah + 5
print ("markah baru:",markah_baru)
# Out:
# markah baru: [75 90 95 70 85]

# %% [markdown]
# AMALI PANDAS

# %%
import pandas as pd

data = {
    "Nama": ["ali","ameer","alim","kasim"],
    "Markah" : [70,85,90,65]
}

# %% [markdown]
# BINA DATAFRAME

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#     Nama  Markah
# 0    ali      70
# 1  ameer      85
# 2   alim      90
# 3  kasim      65

# %% [markdown]
# purata = df["Markah"].mean()
# print("Purata markah:",purata)

# %%
purata = df["Markah"].mean()
print("Purata markah:",purata)
# Out:
# Purata markah: 77.5

# %% [markdown]
# tambah lajur status

# %%
pelajar_cemerlang = df[df["Markah"] < 50]
print("Pelajar yang cemerlang:")
print(pelajar_cemerlang)
# Out:
# Pelajar yang cemerlang:
# Empty DataFrame
# Columns: [Nama, Markah]
# Index: []

# %%
df["status"] = np.where(df["Markah"] < 50, "cemerlang", "lulus")
print(df)
# Out:
#     Nama  Markah status
# 0    ali      70  lulus
# 1  ameer      85  lulus
# 2   alim      90  lulus
# 3  kasim      65  lulus

# %%
def tentukan_gred(markah):
    if markah >= 80:
        return "A"
    elif markah >= 70:
        return "B"
    elif markah >= 60:
        return "C"
    elif markah >= 50:
        return "D"
    else:
        return "E"


df["Grade"] = df["Markah"].apply(tentukan_gred)
print(df)
# Out:
#     Nama  Markah status Grade
# 0    ali      70  lulus     B
# 1  ameer      85  lulus     A
# 2   alim      90  lulus     A
# 3  kasim      65  lulus     C
